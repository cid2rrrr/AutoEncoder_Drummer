# %%
import os
import pickle

import numpy as np
import soundfile as sf
import librosa
import tensorflow as tf

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, ReLU, BatchNormalization, Flatten, Dense, Reshape, Conv2DTranspose, Activation, Lambda
from tensorflow.keras import backend as K
from tensorflow import keras

# %%
class SoundGen:
    def __init__(self, vae, hop_len):
        self.vae = vae
        self.hop_len = hop_len
        self._min_max_norm = MinMaxNorm(0, 1)

    def generate(self, mel, min_max_val):
        gen_mel, latent = self.vae.reconstruct(mel)
        wav = self.convert_mel2wav(gen_mel, min_max_val)
        return wav, latent
    
    def convert_mel2wav(self, mel, min_max_val):
        wavs = []
        for mel, min_max_val in zip(mel, min_max_val):
            # reshape the log-mel
            log_spect = mel[:, :, 0]
            # apply de-norm
            denorm_log_spect = self._min_max_norm.denormalize(
                log_spect, min_max_val['min'], min_max_val['max'])
            # log-spec to spec
            spect = librosa.db_to_amplitude(denorm_log_spect)
            # griffin-lim
            wav = librosa.istft(spect, hop_length=self.hop_len)
            # wav to wav
            wavs.append(wav)
        return wavs

# %%
input_shape=[28,28,1]
conv_filters=[2,4,8]
conv_kernels=[3,5,3]
conv_strides=[1,2,2]
latent_dim=2

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        # self.input_shape = input_shape
        # self.conv_filters = conv_filters
        # self.conv_kernels = conv_kernels
        # self.conv_strides = conv_strides
        # self.latent_dim = latent_dim
        self.reconst_loss_weight = 1000000

        self.encoder = encoder
        self.decoder = decoder

    def _calculate_combined_loss(self, y_traget, y_pred):
        reconst_loss = self._calculate_reconst_loss(y_traget, y_pred)
        kl_loss = self._calculate_kl_loss(y_traget, y_pred)
        combined_loss = self.reconst_loss_weight * reconst_loss + kl_loss
        return combined_loss

    def _calculate_recosnt_loss(self, y_target, y_pred):
        err = y_target - y_pred
        reconst_loss = K.mean(K.square(err), axis=[1,2,3])
        return reconst_loss
    
    def _calculate_kl_loss(self, y_traget, y_pred):
        kl_loss = -0.5 * K.sum(1 + self.log_var - K.square(self.mu) - K.exp(self.log_var), axis=1)
        return kl_loss

    
    def compile(self, lr=1e-6):
        optim = tf.keras.optimizers.Adam(learning_rate=lr)
        self.model.compile(optimizer=optim, loss=)

# %%
input_shape = [256,345,1]
latent_dim = 2

def sample_point_from_normal_distribution(args):
    mu, log_var = args
    epsilon = K.random_normal(shape=K.shape(mu), mean=0., stddev=1.)
    sample_point = mu + K.exp(log_var / 2) * epsilon
    return sample_point

def encoder():
    global shape_before_bottleneck
    en_input = Input(shape=input_shape)

    conv1 = Conv2D(filters=2, kernel_size=3, strides=1, padding='same')(en_input)
    relu1 = ReLU()(conv1)
    bnor1 = BatchNormalization()(relu1)

    conv2 = Conv2D(filters=4, kernel_size=5, strides=2, padding='same')(bnor1)
    relu2 = ReLU()(conv2)
    bnor2 = BatchNormalization()(relu2)
    
    conv3 = Conv2D(filters=8, kernel_size=3, strides=2, padding='same')(bnor2)
    relu3 = ReLU()(conv3)
    bnor3 = BatchNormalization()(relu3)

    shape_before_bottleneck = K.int_shape(bnor3)[1:]
    x = Flatten()(bnor3)

    mu = Dense(latent_dim)(x)
    log_var = Dense(latent_dim)(x)

    en_out = Lambda(sample_point_from_normal_distribution)([mu, log_var])

    return Model(en_input, [mu, log_var, en_out], name='encoder')

# %%
def decoder():
    
    dec_in = Input(shape=(latent_dim,))
    
    num_neurons = np.prod(shape_before_bottleneck)
    x = Dense(num_neurons)(dec_in)
    x = Reshape(shape_before_bottleneck)(x)

    conv3 = Conv2DTranspose(filters=8, kernel_size=3, strides=2, padding='same')(x)
    relu3 = ReLU()(conv3)
    bnor3 = BatchNormalization()(relu3)

    conv2 = Conv2DTranspose(filters=4, kernel_size=5, strides=2, padding='same')(bnor3)
    relu2 = ReLU()(conv2)
    bnor2 = BatchNormalization()(relu2)

    conv1 = Conv2DTranspose(filters=2, kernel_size=3, strides=1, padding='same')(bnor2)
    relu1 = ReLU()(conv1)
    bnor1 = BatchNormalization()(relu1)

    out = Conv2DTranspose(filters=1, kernel_size=3, strides=1, padding='same')(bnor1)
    dec_out = Activation('sigmoid')(out)

    return Model(dec_in, dec_out, name='decoder')

# %%
class own_VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(own_VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name='total_loss')
        self.reconst_loss_tracker = keras.metrics.Mean(name='reconst_loss')
        self.kl_loss_tracker = keras.metrics.Mean(name='kl_loss')

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconst_loss_tracker,
            self.kl_loss_tracker
        ]
    
    def train_stpe(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconst = self.decoder
            reconst_loss = tf.reduce_mean(tf.reduce_sum(keras.losses.binary_crossentropy(data, reconst), axis=(1,2)))
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconst_loss + kl_loss

        grad = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grad, self.trainalble_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconst_loss_tracker.update_state(reconst_loss)
        self.kl_loss_tracker.update_state(kl_loss)

        return {
            'loss' : self.total_loss_tracker.result(),
            'reconst_loss' : self.reconst_loss_tracker.result(),
            'kl_loss' : self.kl_loss_tracker.result(),
        }

# %%
def load_fsdd(spectrograms_path):
    x_train = []
    file_paths = []
    for root, _, file_names in os.walk(spectrograms_path):
        for file_name in file_names:
            file_path = os.path.join(root, file_name)
            spectrogram = np.load(file_path) # (n_bins, n_frames, 1)
            x_train.append(spectrogram)
            file_paths.append(file_path)
    x_train = np.array(x_train)
    x_train = x_train[..., np.newaxis] # -> (3000, 256, 64, 1)
    return x_train, file_paths

# %%
def select_spectrograms(spectrograms,
                        file_paths,
                        min_max_values,
                        num_spectrograms=2):
    sampled_indexes = np.random.choice(range(len(spectrograms)), num_spectrograms)
    sampled_spectrogrmas = spectrograms[sampled_indexes]
    file_paths = [file_paths[index] for index in sampled_indexes]
    sampled_min_max_values = [min_max_values[file_path] for file_path in
                           file_paths]
    print(file_paths)
    print(sampled_min_max_values)
    return sampled_spectrogrmas, sampled_min_max_values

# %%
def save_signals(signals, save_dir, sample_rate=22050):
    for i, signal in enumerate(signals):
        save_path = os.path.join(save_dir, str(i) + ".wav")
        sf.write(save_path, signal, sample_rate)

# %%
imsi = []
SR = 22050

for i in imsi:
    wav = librosa.load(i, sr=SR, mono=True)[0]
    stft = librosa.stfr(wav)[:-1]
    spec = np.abs(stft)
    log_spec = librosa.amplitude_to_db(spec)
    norm = (log_spec - log_spec.min()) / (log_spec.max() - log_spec.min())

# %% [markdown]
# ---

# %%
import os
import pickle

import librosa
import numpy as np


class Loader:
    """Loader is responsible for loading an audio file."""

    def __init__(self, sample_rate, duration, mono):
        self.sample_rate = sample_rate
        self.duration = duration
        self.mono = mono

    def load(self, file_path):
        signal = librosa.load(file_path,
                              sr=self.sample_rate,
                              duration=self.duration,
                              mono=self.mono)[0]
        return signal


class Padder:
    """Padder is responsible to apply padding to an array."""

    def __init__(self, mode="constant"):
        self.mode = mode

    def left_pad(self, array, num_missing_items):
        padded_array = np.pad(array,
                              (num_missing_items, 0),
                              mode=self.mode)
        return padded_array

    def right_pad(self, array, num_missing_items):
        padded_array = np.pad(array,
                              (0, num_missing_items),
                              mode=self.mode)
        return padded_array


class LogSpectrogramExtractor:
    """LogSpectrogramExtractor extracts log spectrograms (in dB) from a
    time-series signal.
    """

    def __init__(self, frame_size, hop_length):
        self.frame_size = frame_size
        self.hop_length = hop_length

    def extract(self, signal):
        stft = librosa.stft(signal,
                            n_fft=self.frame_size,
                            hop_length=self.hop_length)[:-1]
        spectrogram = np.abs(stft)
        log_spectrogram = librosa.amplitude_to_db(spectrogram)
        return log_spectrogram


class MinMaxNormaliser:
    """MinMaxNormaliser applies min max normalisation to an array."""

    def __init__(self, min_val, max_val):
        self.min = min_val
        self.max = max_val

    def normalise(self, array):
        norm_array = (array - array.min()) / (array.max() - array.min())
        norm_array = norm_array * (self.max - self.min) + self.min
        return norm_array

    def denormalise(self, norm_array, original_min, original_max):
        array = (norm_array - self.min) / (self.max - self.min)
        array = array * (original_max - original_min) + original_min
        return array


class Saver:
    """saver is responsible to save features, and the min max values."""

    def __init__(self, feature_save_dir, min_max_values_save_dir):
        self.feature_save_dir = feature_save_dir
        self.min_max_values_save_dir = min_max_values_save_dir

    def save_feature(self, feature, file_path):
        save_path = self._generate_save_path(file_path)
        np.save(save_path, feature)
        return save_path

    def save_min_max_values(self, min_max_values):
        save_path = os.path.join(self.min_max_values_save_dir,
                                 "min_max_values.pkl")
        self._save(min_max_values, save_path)

    @staticmethod
    def _save(data, save_path):
        with open(save_path, "wb") as f:
            pickle.dump(data, f)

    def _generate_save_path(self, file_path):
        file_name = os.path.split(file_path)[1]
        save_path = os.path.join(self.feature_save_dir, file_name + ".npy")
        return save_path


class PreprocessingPipeline:
    """PreprocessingPipeline processes audio files in a directory, applying
    the following steps to each file:
        1- load a file
        2- pad the signal (if necessary)
        3- extracting log spectrogram from signal
        4- normalise spectrogram
        5- save the normalised spectrogram

    Storing the min max values for all the log spectrograms.
    """

    def __init__(self):
        self.padder = None
        self.extractor = None
        self.normaliser = None
        self.saver = None
        self.min_max_values = {}
        self._loader = None
        self._num_expected_samples = None

    @property
    def loader(self):
        return self._loader

    @loader.setter
    def loader(self, loader):
        self._loader = loader
        self._num_expected_samples = int(loader.sample_rate * loader.duration)

    def process(self, audio_files_dir):
        for root, _, files in os.walk(audio_files_dir):
            files = [f for f in files if not f[0] == '.']
            for file in files:
                file_path = os.path.join(root, file)
                self._process_file(file_path)
                print(f"Processed file {file_path}")
        self.saver.save_min_max_values(self.min_max_values)

    def _process_file(self, file_path):
        signal = self.loader.load(file_path)
        if self._is_padding_necessary(signal):
            signal = self._apply_padding(signal)
        feature = self.extractor.extract(signal)
        norm_feature = self.normaliser.normalise(feature)
        save_path = self.saver.save_feature(norm_feature, file_path)
        self._store_min_max_value(save_path, feature.min(), feature.max())

    def _is_padding_necessary(self, signal):
        if len(signal) < self._num_expected_samples:
            return True
        return False

    def _apply_padding(self, signal):
        num_missing_samples = self._num_expected_samples - len(signal)
        padded_signal = self.padder.right_pad(signal, num_missing_samples)
        return padded_signal

    def _store_min_max_value(self, save_path, min_val, max_val):
        self.min_max_values[save_path] = {
            "min": min_val,
            "max": max_val
        }

# %%
FRAME_SIZE = 512
HOP_LENGTH = 256
DURATION = 4  # in seconds
SAMPLE_RATE = 22050
MONO = True

SPECTROGRAMS_SAVE_DIR = "./datasets/fsdd/spectrograms/"
MIN_MAX_VALUES_SAVE_DIR = "./datasets/fsdd/"
FILES_DIR = "./LOOP/"

# instantiate all objects
loader = Loader(SAMPLE_RATE, DURATION, MONO)
padder = Padder()
log_spectrogram_extractor = LogSpectrogramExtractor(FRAME_SIZE, HOP_LENGTH)
min_max_normaliser = MinMaxNormaliser(0, 1)
saver = Saver(SPECTROGRAMS_SAVE_DIR, MIN_MAX_VALUES_SAVE_DIR)

preprocessing_pipeline = PreprocessingPipeline()
preprocessing_pipeline.loader = loader
preprocessing_pipeline.padder = padder
preprocessing_pipeline.extractor = log_spectrogram_extractor
preprocessing_pipeline.normaliser = min_max_normaliser
preprocessing_pipeline.saver = saver

preprocessing_pipeline.process(FILES_DIR)
# Out:
# Processed file ./LOOP/Track(74).wav
# Processed file ./LOOP/dlvbk(95).wav
# Processed file ./LOOP/olbk(17).wav
# Processed file ./LOOP/ovbb(72).wav
# Processed file ./LOOP/OVB80A.wav
# Processed file ./LOOP/Track(23).wav
# Processed file ./LOOP/dlvbk(138).wav
# Processed file ./LOOP/ovbb(25).wav
# Processed file ./LOOP/DLVBK021.wav
# Processed file ./LOOP/02.wav
# Processed file ./LOOP/DLVBK035.wav
# Processed file ./LOOP/OLBK091.wav
# Processed file ./LOOP/DLVBK009.wav
# Processed file ./LOOP/Track(35).wav
# Processed file ./LOOP/OLBK085.wav
# Processed file ./LOOP/OLBK003A.wav
# Processed file ./LOOP/OLBK052.wav
# Processed file ./LOOP/ovbb(33).wav
# Processed file ./LOOP/OLBK046.wav
# Processed file ./LOOP/Track(62).wav
# Processed file ./LOOP/dlvbk(83).wav
# Processed file ./LOOP/ovbb(64).wav
# Processed file ./LOOP/Track(19).wav
# Processed file ./LOOP/dlvbk(102).wav
# Processed file ./LOOP/dlvbk(17).wav
# Processed file ./LOOP/OLBK047.wav
# Processed file ./LOOP/OLBK053.wav
# Processed file ./LOOP/OLBK084.wav
# Processed file ./LOOP/dlvbk(40).wav
# Processed file ./LOOP/OLBK090.wav
# Processed file ./LOOP/ovbb(48).wav
# Processed file ./LOOP/DLVBK034.wav
# Processed file ./LOOP/03.wav
# Processed file ./LOOP/Track(58).wav
# Processed file ./LOOP/dlvbk(7).wav
# Processed file ./LOOP/dlvbk(143).wav
# Processed file ./LOOP/dlvbk(56).wav
# Processed file ./LOOP/DLVBK168.wav
# Processed file ./LOOP/Track(101).wav
# Processed file ./LOOP/dlvbk(114).wav
# Processed file ./LOOP/dlvbk(99).wav
# Processed file ./LOOP/ovbb(91).wav
# Processed file ./LOOP/dlvbk(76).wav
# Processed file ./LOOP/Track(121).wav
# Processed file ./LOOP/Track(97).wav
# Processed file ./LOOP/Track(78).wav
# Processed file ./LOOP/OVB80B.wav
# Processed file ./LOOP/DLVBK156.wav
# Processed file ./LOOP/dlvbk(21).wav
# Processed file ./LOOP/ovbb(29).wav
# Processed file ./LOOP/DLVBK181.wav
# Processed file ./LOOP/OLBK015B.wav
# Processed file ./LOOP/dlvbk(134).wav
# Processed file ./LOOP/DLVBK036.wav
# Processed file ./LOOP/01.wav
# Processed file ./LOOP/OLBK086.wav
# Processed file ./LOOP/dlvbk(37).wav
# Processed file ./LOOP/OLBK092.wav
# Processed file ./LOOP/OLBK079.wav
# Processed file ./LOOP/OLBK003B.wav
# Processed file ./LOOP/Track(39).wav
# Processed file ./LOOP/OLBK045.wav
# Processed file ./LOOP/dlvbk(122).wav
# Processed file ./LOOP/OLBK051.wav
# Processed file ./LOOP/ovbb(87).wav
# Processed file ./LOOP/dlvbk(60).wav
# Processed file ./LOOP/ovbb(68).wav
# Processed file ./LOOP/Track(81).wav
# Processed file ./LOOP/ovbb(13).wav
# Processed file ./LOOP/Track(15).wav
# Processed file ./LOOP/ovbb(44).wav
# Processed file ./LOOP/olbk(21).wav
# Processed file ./LOOP/OLBK078.wav
# Processed file ./LOOP/Track(42).wav
# Processed file ./LOOP/OLBK093.wav
# Processed file ./LOOP/OLBK087.wav
# Processed file ./LOOP/DLVBK023.wav
# Processed file ./LOOP/DLVBK037.wav
# Processed file ./LOOP/olbk(37).wav
# Processed file ./LOOP/ovbb(52).wav
# Processed file ./LOOP/Track(54).wav
# Processed file ./LOOP/DLVBK157.wav
# Processed file ./LOOP/dlvbk(118).wav
# Processed file ./LOOP/dlvbk(119).wav
# Processed file ./LOOP/OGBK043.wav
# Processed file ./LOOP/Track(55).wav
# Processed file ./LOOP/DLVBK147.wav
# Processed file ./LOOP/olbk(36).wav
# Processed file ./LOOP/ovbb(53).wav
# Processed file ./LOOP/Track(43).wav
# Processed file ./LOOP/OLBK083.wav
# Processed file ./LOOP/OLBK097.wav
# Processed file ./LOOP/10.wav
# Processed file ./LOOP/DLVBK033.wav
# Processed file ./LOOP/04.wav
# Processed file ./LOOP/ovbb(45).wav
# Processed file ./LOOP/OLBK040.wav
# Processed file ./LOOP/OLBK054.wav
# Processed file ./LOOP/olbk(20).wav
# Processed file ./LOOP/OLBK068.wav
# Processed file ./LOOP/Track(14).wav
# Processed file ./LOOP/ovbb(12).wav
# Processed file ./LOOP/Track(80).wav
# Processed file ./LOOP/ovbb(86).wav
# Processed file ./LOOP/dlvbk(61).wav
# Processed file ./LOOP/ovbb(69).wav
# Processed file ./LOOP/OLBK069.wav
# Processed file ./LOOP/ovbb.wav
# Processed file ./LOOP/Track(38).wav
# Processed file ./LOOP/OLBK055.wav
# Processed file ./LOOP/dlvbk(123).wav
# Processed file ./LOOP/05.wav
# Processed file ./LOOP/11.wav
# Processed file ./LOOP/OLBK096.wav
# Processed file ./LOOP/dlvbk(36).wav
# Processed file ./LOOP/OLBK082.wav
# Processed file ./LOOP/dlvbk(135).wav
# Processed file ./LOOP/DLVBK146.wav
# Processed file ./LOOP/OGBK056.wav
# Processed file ./LOOP/dlvbk(20).wav
# Processed file ./LOOP/ovbb(28).wav
# Processed file ./LOOP/Track(96).wav
# Processed file ./LOOP/Track(79).wav
# Processed file ./LOOP/dlvbk(98).wav
# Processed file ./LOOP/ovbb(90).wav
# Processed file ./LOOP/dlvbk(77).wav
# Processed file ./LOOP/dlvbk(115).wav
# Processed file ./LOOP/Track.wav
# Processed file ./LOOP/dlvbk(57).wav
# Processed file ./LOOP/Track(100).wav
# Processed file ./LOOP/DLVBK150.wav
# Processed file ./LOOP/Track(59).wav
# Processed file ./LOOP/dlvbk(142).wav
# Processed file ./LOOP/dlvbk(6).wav
# Processed file ./LOOP/OGBK083.wav
# Processed file ./LOOP/Track(116).wav
# Processed file ./LOOP/DLVBK018.wav
# Processed file ./LOOP/dlvbk(41).wav
# Processed file ./LOOP/OLBK094.wav
# Processed file ./LOOP/OLBK080.wav
# Processed file ./LOOP/ovbb(49).wav
# Processed file ./LOOP/07.wav
# Processed file ./LOOP/OLBK043.wav
# Processed file ./LOOP/dlvbk(16).wav
# Processed file ./LOOP/Track(18).wav
# Processed file ./LOOP/dlvbk(103).wav
# Processed file ./LOOP/dlvbk(82).wav
# Processed file ./LOOP/ovbb(65).wav
# Processed file ./LOOP/Track(63).wav
# Processed file ./LOOP/OLBK042.wav
# Processed file ./LOOP/ovbb(32).wav
# Processed file ./LOOP/OLBK056.wav
# Processed file ./LOOP/DLVBK031.wav
# Processed file ./LOOP/06.wav
# Processed file ./LOOP/Track(34).wav
# Processed file ./LOOP/ovbb(24).wav
# Processed file ./LOOP/Track(22).wav
# Processed file ./LOOP/OGBK041.wav
# Processed file ./LOOP/dlvbk(139).wav
# Processed file ./LOOP/dlvbk(94).wav
# Processed file ./LOOP/olbk(16).wav
# Processed file ./LOOP/ovbb(73).wav
# Processed file ./LOOP/Track(75).wav
# Processed file ./LOOP/Track(127).wav
# Processed file ./LOOP/dlvbk(70).wav
# Processed file ./LOOP/ovbb(78).wav
# Processed file ./LOOP/Track(91).wav
# Processed file ./LOOP/DLVBK136.wav
# Processed file ./LOOP/dlvbk(27).wav
# Processed file ./LOOP/Track(29).wav
# Processed file ./LOOP/dlvbk(132).wav
# Processed file ./LOOP/OVB92.wav
# Processed file ./LOOP/DLVBK056.wav
# Processed file ./LOOP/OLBK009A.wav
# Processed file ./LOOP/dlvbk(31).wav
# Processed file ./LOOP/ovbb(39).wav
# Processed file ./LOOP/OLBK019.wav
# Processed file ./LOOP/dlvbk(124).wav
# Processed file ./LOOP/OLBK031.wav
# Processed file ./LOOP/OLBK025.wav
# Processed file ./LOOP/OVB79.wav
# Processed file ./LOOP/dlvbk(89).wav
# Processed file ./LOOP/ovbb(81).wav
# Processed file ./LOOP/dlvbk(66).wav
# Processed file ./LOOP/Track(87).wav
# Processed file ./LOOP/Track(68).wav
# Processed file ./LOOP/OGBK120a.wav
# Processed file ./LOOP/ovbb(15).wav
# Processed file ./LOOP/Track(13).wav
# Processed file ./LOOP/dlvbk(108).wav
# Processed file ./LOOP/olbk(27).wav
# Processed file ./LOOP/OLBK024.wav
# Processed file ./LOOP/ovbb(42).wav
# Processed file ./LOOP/OLBK030.wav
# Processed file ./LOOP/OLBK018.wav
# Processed file ./LOOP/Track(44).wav
# Processed file ./LOOP/DLVBK043.wav
# Processed file ./LOOP/ovbb(54).wav
# Processed file ./LOOP/olbk(31).wav
# Processed file ./LOOP/Track(52).wav
# Processed file ./LOOP/dlvbk(149).wav
# Processed file ./LOOP/DLVBK123.wav
# Processed file ./LOOP/olbk(6).wav
# Processed file ./LOOP/Track(72).wav
# Processed file ./LOOP/dlvbk(93).wav
# Processed file ./LOOP/ovbb(74).wav
# Processed file ./LOOP/olbk(11).wav
# Processed file ./LOOP/Track(25).wav
# Processed file ./LOOP/OGBK031.wav
# Processed file ./LOOP/ovbb(23).wav
# Processed file ./LOOP/OLBK009B.wav
# Processed file ./LOOP/DLVBK041.wav
# Processed file ./LOOP/OVB91.wav
# Processed file ./LOOP/Track(33).wav
# Processed file ./LOOP/dlvbk(128).wav
# Processed file ./LOOP/OLBK026.wav
# Processed file ./LOOP/ovbb(35).wav
# Processed file ./LOOP/OLBK032.wav
# Processed file ./LOOP/Track(64).wav
# Processed file ./LOOP/ovbb(6).wav
# Processed file ./LOOP/dlvbk(85).wav
# Processed file ./LOOP/ovbb(62).wav
# Processed file ./LOOP/dlvbk(104).wav
# Processed file ./LOOP/OGBK120b.wav
# Processed file ./LOOP/dlvbk(11).wav
# Processed file ./LOOP/ovbb(19).wav
# Processed file ./LOOP/Track(6).wav
# Processed file ./LOOP/OLBK033.wav
# Processed file ./LOOP/Track(48).wav
# Processed file ./LOOP/dlvbk(153).wav
# Processed file ./LOOP/OLBK027.wav
# Processed file ./LOOP/DLVBK097.wav
# Processed file ./LOOP/dlvbk.wav
# Processed file ./LOOP/DLVBK068.wav
# Processed file ./LOOP/dlvbk(46).wav
# Processed file ./LOOP/Track(111).wav
# Processed file ./LOOP/DLVBK040.wav
# Processed file ./LOOP/OLBK009C.wav
# Processed file ./LOOP/dlvbk(145).wav
# Processed file ./LOOP/Track(107).wav
# Processed file ./LOOP/dlvbk(50).wav
# Processed file ./LOOP/DLVBK108.wav
# Processed file ./LOOP/ovbb(58).wav
# Processed file ./LOOP/dlvbk(112).wav
# Processed file ./LOOP/dlvbk(113).wav
# Processed file ./LOOP/dlvbk(51).wav
# Processed file ./LOOP/ovbb(59).wav
# Processed file ./LOOP/DLVBK124.wav
# Processed file ./LOOP/DLVBK130.wav
# Processed file ./LOOP/dlvbk(144).wav
# Processed file ./LOOP/OVB13A.wav
# Processed file ./LOOP/DLVBK078.wav
# Processed file ./LOOP/dlvbk(47).wav
# Processed file ./LOOP/Track(110).wav
# Processed file ./LOOP/DLVBK050.wav
# Processed file ./LOOP/OLBK023.wav
# Processed file ./LOOP/Track(49).wav
# Processed file ./LOOP/OLBK037.wav
# Processed file ./LOOP/DLVBK093.wav
# Processed file ./LOOP/DLVBK087.wav
# Processed file ./LOOP/dlvbk(10).wav
# Processed file ./LOOP/ovbb(18).wav
# Processed file ./LOOP/Track(7).wav
# Processed file ./LOOP/dlvbk(105).wav
# Processed file ./LOOP/ovbb(7).wav
# Processed file ./LOOP/dlvbk(84).wav
# Processed file ./LOOP/ovbb(63).wav
# Processed file ./LOOP/Track(65).wav
# Processed file ./LOOP/DLVBK086.wav
# Processed file ./LOOP/DLVBK092.wav
# Processed file ./LOOP/ovbb(34).wav
# Processed file ./LOOP/OLBK022.wav
# Processed file ./LOOP/DLVBK045.wav
# Processed file ./LOOP/Track(32).wav
# Processed file ./LOOP/DLVBK079.wav
# Processed file ./LOOP/dlvbk(129).wav
# Processed file ./LOOP/ovbb(22).wav
# Processed file ./LOOP/DLVBK125.wav
# Processed file ./LOOP/Track(24).wav
# Processed file ./LOOP/dlvbk(92).wav
# Processed file ./LOOP/ovbb(75).wav
# Processed file ./LOOP/olbk(10).wav
# Processed file ./LOOP/Track(73).wav
# Processed file ./LOOP/Track(53).wav
# Processed file ./LOOP/dlvbk(148).wav
# Processed file ./LOOP/DLVBK133.wav
# Processed file ./LOOP/DLVBK127.wav
# Processed file ./LOOP/olbk(7).wav
# Processed file ./LOOP/OVB13B.wav
# Processed file ./LOOP/ovbb(55).wav
# Processed file ./LOOP/olbk(30).wav
# Processed file ./LOOP/Track(45).wav
# Processed file ./LOOP/OVB97.wav
# Processed file ./LOOP/OVB83.wav
# Processed file ./LOOP/olbk(26).wav
# Processed file ./LOOP/OLBK034.wav
# Processed file ./LOOP/ovbb(43).wav
# Processed file ./LOOP/OLBK020.wav
# Processed file ./LOOP/DLVBK090.wav
# Processed file ./LOOP/Track(12).wav
# Processed file ./LOOP/dlvbk(109).wav
# Processed file ./LOOP/ovbb(14).wav
# Processed file ./LOOP/Track(86).wav
# Processed file ./LOOP/Track(69).wav
# Processed file ./LOOP/dlvbk(88).wav
# Processed file ./LOOP/ovbb(80).wav
# Processed file ./LOOP/dlvbk(67).wav
# Processed file ./LOOP/DLVBK091.wav
# Processed file ./LOOP/dlvbk(125).wav
# Processed file ./LOOP/OLBK021.wav
# Processed file ./LOOP/OLBK035.wav
# Processed file ./LOOP/DLVBK046.wav
# Processed file ./LOOP/dlvbk(30).wav
# Processed file ./LOOP/ovbb(38).wav
# Processed file ./LOOP/Track(28).wav
# Processed file ./LOOP/dlvbk(133).wav
# Processed file ./LOOP/dlvbk(26).wav
# Processed file ./LOOP/Track(90).wav
# Processed file ./LOOP/Track(126).wav
# Processed file ./LOOP/dlvbk(71).wav
# Processed file ./LOOP/olbk(4).wav
# Processed file ./LOOP/ovb(2).wav
# Processed file ./LOOP/Track(50).wav
# Processed file ./LOOP/Track(109).wav
# Processed file ./LOOP/olbk(33).wav
# Processed file ./LOOP/ovbb(56).wav
# Processed file ./LOOP/DLVBK063.wav
# Processed file ./LOOP/DLVBK077.wav
# Processed file ./LOOP/Track(46).wav
# Processed file ./LOOP/ovbb(40).wav
# Processed file ./LOOP/olbk(25).wav
# Processed file ./LOOP/OLBK004.wav
# Processed file ./LOOP/dlvbk(48).wav
# Processed file ./LOOP/DLVBK088.wav
# Processed file ./LOOP/Track(11).wav
# Processed file ./LOOP/Track(8).wav
# Processed file ./LOOP/ovbb(17).wav
# Processed file ./LOOP/Track(85).wav
# Processed file ./LOOP/OLBK050B.wav
# Processed file ./LOOP/dlvbk(64).wav
# Processed file ./LOOP/ovbb(83).wav
# Processed file ./LOOP/ovbb(8).wav
# Processed file ./LOOP/OLBK005.wav
# Processed file ./LOOP/dlvbk(126).wav
# Processed file ./LOOP/OLBK011.wav
# Processed file ./LOOP/OLBK039.wav
# Processed file ./LOOP/dlvbk(33).wav
# Processed file ./LOOP/DLVBK076.wav
# Processed file ./LOOP/DLVBK062.wav
# Processed file ./LOOP/dlvbk(130).wav
# Processed file ./LOOP/dlvbk(25).wav
# Processed file ./LOOP/DLVBK102.wav
# Processed file ./LOOP/DLVBK116.wav
# Processed file ./LOOP/Track(93).wav
# Processed file ./LOOP/dlvbk(72).wav
# Processed file ./LOOP/dlvbk(110).wav
# Processed file ./LOOP/DLVBK114.wav
# Processed file ./LOOP/Track(105).wav
# Processed file ./LOOP/dlvbk(52).wav
# Processed file ./LOOP/olbk(8).wav
# Processed file ./LOOP/dlvbk(3).wav
# Processed file ./LOOP/dlvbk(44).wav
# Processed file ./LOOP/DLVBK048.wav
# Processed file ./LOOP/olbk(29).wav
# Processed file ./LOOP/Track(113).wav
# Processed file ./LOOP/dlvbk(151).wav
# Processed file ./LOOP/OLBK013.wav
# Processed file ./LOOP/Track(4).wav
# Processed file ./LOOP/dlvbk(13).wav
# Processed file ./LOOP/OGBK122b.wav
# Processed file ./LOOP/dlvbk(106).wav
# Processed file ./LOOP/ovbb(60).wav
# Processed file ./LOOP/dlvbk(68).wav
# Processed file ./LOOP/OLBK050A.wav
# Processed file ./LOOP/ovbb(4).wav
# Processed file ./LOOP/dlvbk(87).wav
# Processed file ./LOOP/Track(66).wav
# Processed file ./LOOP/Track(89).wav
# Processed file ./LOOP/OLBK012.wav
# Processed file ./LOOP/OLBK006.wav
# Processed file ./LOOP/ovbb(37).wav
# Processed file ./LOOP/Track(31).wav
# Processed file ./LOOP/DLVBK049.wav
# Processed file ./LOOP/DLVBK061.wav
# Processed file ./LOOP/ovbb(21).wav
# Processed file ./LOOP/dlvbk(29).wav
# Processed file ./LOOP/Track(27).wav
# Processed file ./LOOP/DLVBK115.wav
# Processed file ./LOOP/DLVBK101.wav
# Processed file ./LOOP/olbk(13).wav
# Processed file ./LOOP/ovbb(76).wav
# Processed file ./LOOP/dlvbk(91).wav
# Processed file ./LOOP/Track(70).wav
# Processed file ./LOOP/Track(71).wav
# Processed file ./LOOP/Track(128).wav
# Processed file ./LOOP/olbk(12).wav
# Processed file ./LOOP/ovbb(77).wav
# Processed file ./LOOP/dlvbk(90).wav
# Processed file ./LOOP/Track(26).wav
# Processed file ./LOOP/ovbb(20).wav
# Processed file ./LOOP/dlvbk(28).wav
# Processed file ./LOOP/DLVBK059.wav
# Processed file ./LOOP/Track(30).wav
# Processed file ./LOOP/DLVBK065.wav
# Processed file ./LOOP/OLBK002.wav
# Processed file ./LOOP/OLBK016.wav
# Processed file ./LOOP/ovbb(36).wav
# Processed file ./LOOP/Track(67).wav
# Processed file ./LOOP/Track(88).wav
# Processed file ./LOOP/ovbb(61).wav
# Processed file ./LOOP/dlvbk(69).wav
# Processed file ./LOOP/ovbb(5).wav
# Processed file ./LOOP/dlvbk(86).wav
# Processed file ./LOOP/dlvbk(107).wav
# Processed file ./LOOP/Track(5).wav
# Processed file ./LOOP/dlvbk(12).wav
# Processed file ./LOOP/dlvbk(150).wav
# Processed file ./LOOP/OLBK017.wav
# Processed file ./LOOP/DLVBK064.wav
# Processed file ./LOOP/dlvbk(45).wav
# Processed file ./LOOP/olbk(28).wav
# Processed file ./LOOP/Track(112).wav
# Processed file ./LOOP/olbk(9).wav
# Processed file ./LOOP/dlvbk(146).wav
# Processed file ./LOOP/dlvbk(2).wav
# Processed file ./LOOP/DLVBK110.wav
# Processed file ./LOOP/Track(104).wav
# Processed file ./LOOP/DLVBK138.wav
# Processed file ./LOOP/dlvbk(53).wav
# Processed file ./LOOP/dlvbk(111).wav
# Processed file ./LOOP/Funky Constellation - Street Talk (Break 2).wav
# Processed file ./LOOP/Track(124).wav
# Processed file ./LOOP/dlvbk(73).wav
# Processed file ./LOOP/Track(92).wav
# Processed file ./LOOP/dlvbk(24).wav
# Processed file ./LOOP/dlvbk(131).wav
# Processed file ./LOOP/dlvbk(32).wav
# Processed file ./LOOP/DLVBK066.wav
# Processed file ./LOOP/dlvbk(127).wav
# Processed file ./LOOP/OLBK029.wav
# Processed file ./LOOP/dlvbk(65).wav
# Processed file ./LOOP/ovbb(82).wav
# Processed file ./LOOP/ovbb(9).wav
# Processed file ./LOOP/Track(84).wav
# Processed file ./LOOP/Track(9).wav
# Processed file ./LOOP/ovbb(16).wav
# Processed file ./LOOP/Track(10).wav
# Processed file ./LOOP/OLBK028.wav
# Processed file ./LOOP/ovbb(41).wav
# Processed file ./LOOP/olbk(24).wav
# Processed file ./LOOP/dlvbk(49).wav
# Processed file ./LOOP/OLBK014.wav
# Processed file ./LOOP/Track(47).wav
# Processed file ./LOOP/Track(108).wav
# Processed file ./LOOP/olbk(32).wav
# Processed file ./LOOP/ovbb(57).wav
# Processed file ./LOOP/DLVBK107.wav
# Processed file ./LOOP/olbk(5).wav
# Processed file ./LOOP/ovb(3).wav
# Processed file ./LOOP/Track(51).wav
# Processed file ./LOOP/olbk.wav
# Processed file ./LOOP/dlvbk(116).wav
# Processed file ./LOOP/DLVBK148.wav
# Processed file ./LOOP/dlvbk(54).wav
# Processed file ./LOOP/Track(103).wav
# Processed file ./LOOP/dlvbk(141).wav
# Processed file ./LOOP/dlvbk(5).wav
# Processed file ./LOOP/OLBK098.wav
# Processed file ./LOOP/dlvbk(42).wav
# Processed file ./LOOP/OLBK076B.wav
# Processed file ./LOOP/OLBK073.wav
# Processed file ./LOOP/OLBK067.wav
# Processed file ./LOOP/Track(2).wav
# Processed file ./LOOP/dlvbk(15).wav
# Processed file ./LOOP/dlvbk(100).wav
# Processed file ./LOOP/ovbb(66).wav
# Processed file ./LOOP/ovbb(89).wav
# Processed file ./LOOP/ovbb(2).wav
# Processed file ./LOOP/dlvbk(81).wav
# Processed file ./LOOP/Track(60).wav
# Processed file ./LOOP/ovbb(31).wav
# Processed file ./LOOP/OLBK066.wav
# Processed file ./LOOP/OLBK072.wav
# Processed file ./LOOP/dlvbk(39).wav
# Processed file ./LOOP/Track(37).wav
# Processed file ./LOOP/OLBK099.wav
# Processed file ./LOOP/DLVBK001.wav
# Processed file ./LOOP/ovbb(27).wav
# Processed file ./LOOP/OGBK065.wav
# Processed file ./LOOP/Track(21).wav
# Processed file ./LOOP/ovbb(70).wav
# Processed file ./LOOP/olbk(15).wav
# Processed file ./LOOP/dlvbk(78).wav
# Processed file ./LOOP/dlvbk(97).wav
# Processed file ./LOOP/Track(76).wav
# Processed file ./LOOP/Track(99).wav
# Processed file ./LOOP/olbk(2).wav
# Processed file ./LOOP/Track(56).wav
# Processed file ./LOOP/dlvbk(9).wav
# Processed file ./LOOP/ovbb(50).wav
# Processed file ./LOOP/olbk(35).wav
# Processed file ./LOOP/dlvbk(58).wav
# Processed file ./LOOP/DLVBK003.wav
# Processed file ./LOOP/08.wav
# Processed file ./LOOP/Track(40).wav
# Processed file ./LOOP/OLBK076A.wav
# Processed file ./LOOP/OLBK064.wav
# Processed file ./LOOP/olbk(23).wav
# Processed file ./LOOP/Track(119).wav
# Processed file ./LOOP/ovbb(46).wav
# Processed file ./LOOP/OLBK070.wav
# Processed file ./LOOP/Track(17).wav
# Processed file ./LOOP/ovbb(11).wav
# Processed file ./LOOP/dlvbk(19).wav
# Processed file ./LOOP/Track(83).wav
# Processed file ./LOOP/dlvbk(62).wav
# Processed file ./LOOP/dlvbk(120).wav
# Processed file ./LOOP/OLBK071.wav
# Processed file ./LOOP/OLBK065.wav
# Processed file ./LOOP/dlvbk(35).wav
# Processed file ./LOOP/09.wav
# Processed file ./LOOP/DLVBK002.wav
# Processed file ./LOOP/DLVBK016.wav
# Processed file ./LOOP/dlvbk(136).wav
# Processed file ./LOOP/dlvbk(23).wav
# Processed file ./LOOP/DLVBK176.wav
# Processed file ./LOOP/Track(95).wav
# Processed file ./LOOP/dlvbk(74).wav
# Processed file ./LOOP/Track(123).wav
# Processed file ./LOOP/olbk(19).wav
# Processed file ./LOOP/dlvbk(75).wav
# Processed file ./LOOP/Track(122).wav
# Processed file ./LOOP/olbk(18).wav
# Processed file ./LOOP/ovbb(92).wav
# Processed file ./LOOP/Track(94).wav
# Processed file ./LOOP/OLBK041B.wav
# Processed file ./LOOP/dlvbk(22).wav
# Processed file ./LOOP/dlvbk(137).wav
# Processed file ./LOOP/dlvbk(34).wav
# Processed file ./LOOP/dlvbk(121).wav
# Processed file ./LOOP/OLBK061.wav
# Processed file ./LOOP/OLBK075.wav
# Processed file ./LOOP/OLBK049.wav
# Processed file ./LOOP/dlvbk(63).wav
# Processed file ./LOOP/ovbb(84).wav
# Processed file ./LOOP/Track(82).wav
# Processed file ./LOOP/ovbb(10).wav
# Processed file ./LOOP/dlvbk(18).wav
# Processed file ./LOOP/Track(16).wav
# Processed file ./LOOP/OLBK048.wav
# Processed file ./LOOP/OLBK074.wav
# Processed file ./LOOP/olbk(22).wav
# Processed file ./LOOP/Track(118).wav
# Processed file ./LOOP/ovbb(47).wav
# Processed file ./LOOP/OLBK060.wav
# Processed file ./LOOP/DLVBK007.wav
# Processed file ./LOOP/DLVBK013.wav
# Processed file ./LOOP/Track(41).wav
# Processed file ./LOOP/OLBK100.wav
# Processed file ./LOOP/ovbb(51).wav
# Processed file ./LOOP/olbk(34).wav
# Processed file ./LOOP/dlvbk(59).wav
# Processed file ./LOOP/olbk(3).wav
# Processed file ./LOOP/Track(57).wav
# Processed file ./LOOP/dlvbk(8).wav
# Processed file ./LOOP/Track(77).wav
# Processed file ./LOOP/ovbb(71).wav
# Processed file ./LOOP/olbk(14).wav
# Processed file ./LOOP/dlvbk(79).wav
# Processed file ./LOOP/dlvbk(96).wav
# Processed file ./LOOP/OLBK041A.wav
# Processed file ./LOOP/Track(20).wav
# Processed file ./LOOP/DLVBK165.wav
# Processed file ./LOOP/ovbb(26).wav
# Processed file ./LOOP/DLVBK039.wav
# Processed file ./LOOP/Track(36).wav
# Processed file ./LOOP/OLBK089.wav
# Processed file ./LOOP/ovbb(30).wav
# Processed file ./LOOP/OLBK062.wav
# Processed file ./LOOP/dlvbk(38).wav
# Processed file ./LOOP/Track(61).wav
# Processed file ./LOOP/ovbb(67).wav
# Processed file ./LOOP/ovbb(88).wav
# Processed file ./LOOP/ovbb(3).wav
# Processed file ./LOOP/dlvbk(80).wav
# Processed file ./LOOP/dlvbk(101).wav
# Processed file ./LOOP/Track(3).wav
# Processed file ./LOOP/dlvbk(14).wav
# Processed file ./LOOP/ovb.wav
# Processed file ./LOOP/OLBK063.wav
# Processed file ./LOOP/OLBK077.wav
# Processed file ./LOOP/OLBK088.wav
# Processed file ./LOOP/DLVBK004.wav
# Processed file ./LOOP/Track(114).wav
# Processed file ./LOOP/dlvbk(43).wav
# Processed file ./LOOP/DLVBK038.wav
# Processed file ./LOOP/dlvbk(4).wav
# Processed file ./LOOP/dlvbk(140).wav
# Processed file ./LOOP/DLVBK164.wav
# Processed file ./LOOP/OGBK048.wav
# Processed file ./LOOP/DLVBK170.wav
# Processed file ./LOOP/dlvbk(55).wav
# Processed file ./LOOP/Track(102).wav
# Processed file ./LOOP/dlvbk(117).wav

# %%
spectrograms_path = './datasets/fsdd/spectrograms/'
x_train = []
for root, _, file_names in os.walk(spectrograms_path):
    for file_name in file_names:
        file_path = os.path.join(root, file_name)
        spectrogram = np.load(file_path) # (n_bins, n_frames, 1)
        x_train.append(spectrogram)
x_train = np.array(x_train)
x_train = x_train[..., np.newaxis] # -> (3000, 256, 64, 1)

# %%
x_train.shape
# Out:
# (604, 256, 345, 1)

# %%
encoder = encoder()

# %%
decoder = decoder()

# %%
vae = own_VAE(encoder=encoder, decoder=decoder)

# %%
vae.compile(optimizer=tf.keras.optimizers.Adam())

# %%
vae.fit(x_train, epochs=100, batch_size=16)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/wn/fhcj6_9d2qb5d0pw_xw20ky80000gn/T/ipykernel_7065/858962586.py in <cell line: 1>()
# ----> 1 vae.fit(x_train, epochs=100, batch_size=16)
#
# ~/miniforge3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/miniforge3/lib/python3.9/site-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# NotImplementedError: in user code:
#
#     File "/Users/cooky/miniforge3/lib/python3.9/site-packages/keras/engine/training.py", line 1051, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/cooky/miniforge3/lib/python3.9/site-packages/keras/engine/training.py", line 1040, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/cooky/miniforge3/lib/python3.9/site-packages/keras/engine/training.py", line 1030, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/cooky/miniforge3/lib/python3.9/site-packages/keras/engine/training.py", line 889, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/cooky/miniforge3/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/cooky/miniforge3/lib/python3.9/site-packages/keras/engine/training.py", line 517, in call
#         raise NotImplementedError('Unimplemented `tf.keras.Model.call()`: if you '
#
#     NotImplementedError: Exception encountered when calling layer "own_vae_2" (type own_VAE).
#
#     Unimplemented `tf.keras.Model.call()`: if you intend to create a `Model` with the Functional API, please provide `inputs` and `outputs` arguments. Otherwise, subclass `Model` with an overridden `call()` method.
#
#     Call arguments received by layer "own_vae_2" (type own_VAE):
#       • inputs=tf.Tensor(shape=(None, 256, 345, 1), dtype=float32)
#       • training=True
#       • mask=None
